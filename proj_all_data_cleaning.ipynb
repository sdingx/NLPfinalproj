# %%
# basic data analytics
import pandas as pd
import numpy as np
import sklearn
import pickle

# nlp modules
import nltk
import spacy
import re

import multiprocessing
import string

from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfTransformer, TfidfVectorizer


import gensim
from gensim import corpora, models
from gensim.models.ldamulticore import LdaMulticore
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
import warnings

# warnings.simplefilter('once')
warnings.simplefilter('ignore')

num_processors = multiprocessing.cpu_count()
num_processors

workers = num_processors-1

print(f'Using {workers} workers')
# Out:
# Using 7 workers

# %%
# %%time
df_news_final_project = pd.read_parquet('https://storage.googleapis.com/msca-bdp-data-open/news_final_project/news_final_project.parquet', engine='pyarrow')
df_news_final_project.shape
# Out:
# (200332, 5)

# %%
# df_news_final_project.to_csv("/home/jupyter/df_news.csv")

# %%
df_news_final_project.head(3)
# Out:
#                                                  url        date language  \
# 0  http://en.people.cn/n3/2021/0318/c90000-983012...  2021-03-18       en
# 1  http://newsparliament.com/2020/02/27/children-...  2020-02-27       en
# 2                   http://www.dataweek.co.za/12835r  2021-03-26       en
#
#                                                title  \
# 0  Artificial intelligence improves parking effic...
# 1  Children With Autism Saw Their Learning and So...
# 2  Forget ML, AI and Industry 4.0 – obsolescence ...
#
#                                                 text
# 0  \n\nArtificial intelligence improves parking e...
# 1  \nChildren With Autism Saw Their Learning and ...
# 2  \n\nForget ML, AI and Industry 4.0 – obsolesce...

# %%
# %%time
# clean up tabs
df_news_final_project['text_clean'] = df_news_final_project['text'].apply(lambda x: x.replace('\t', ' '))

# clean up links
df_news_final_project['text_clean'] = df_news_final_project['text_clean'].apply(lambda x: x.replace(r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)', ''))

# clean up remnants of web crawls
df_news_final_project['text_clean'] = df_news_final_project['text_clean'].apply(lambda x: x.replace(r'&#\d+;', ''))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs

# %%
df_news_final_project.head(2)
# Out:
#                                                  url        date language  \
# 0  http://en.people.cn/n3/2021/0318/c90000-983012...  2021-03-18       en
# 1  http://newsparliament.com/2020/02/27/children-...  2020-02-27       en
#
#                                                title  \
# 0  Artificial intelligence improves parking effic...
# 1  Children With Autism Saw Their Learning and So...
#
#                                                 text  \
# 0  \n\nArtificial intelligence improves parking e...
# 1  \nChildren With Autism Saw Their Learning and ...
#
#                                           text_clean
# 0  \n\nArtificial intelligence improves parking e...
# 1  \nChildren With Autism Saw Their Learning and ...

# %%
# %%time
notitle = []
for i in df_news_final_project.index.values:
    notitle.append(df_news_final_project['text_clean'][i].replace(df_news_final_project['title'][i], 'Hahahah 23, 2026')) # replace by this chunk so title can also be split by pattern

df_news_final_project['text_notitle'] = notitle

# drop everything after string 'for more information'ABC
df_news_final_project['text_notitle'] = df_news_final_project['text_notitle'].str.split(r'[F|f]or more information', expand=True)[0]
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs

# %%
# %%time

pattern = r'(\w{3,10}\.*\s\d{1,2}\,*\s20\d{2})|(\d{1,2}\s\w{3,10}\.*\s20\d{2})|\n+'
df_news_final_project['split'] = df_news_final_project['text_notitle'].apply(lambda x: re.split(pattern=pattern, string=x))
df_news_final_project['split_len'] = df_news_final_project['split'].apply(lambda x: len(x))
# Out:
# CPU times: user 6min 3s, sys: 1.89 s, total: 6min 5s
# Wall time: 6min 5s

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

def get_most_similar(index):
    '''
    This function takes in an index of the dataframe and returns the most similar text to the title,
    filtering out other unnecessary texts.
    '''

    title = df_news_final_project['title'][index]
    texts = df_news_final_project['split'][index]

    # print('Original:\n', texts)

    # drop none ones
    texts = [x for x in texts if x != None]

    # print('Dropping None:\n', texts)

    # print('Dropping more period than capital:\n', texts)

    # take out texts that are too short
    texts = [x for x in texts if len(x) > 150]

    # print('Dropping too short:\n', texts)

    # drop texts with Tab patterns
    pattern = r'([A-Z][a-z]+(\n|\t)+){4}'
    texts =  [re.sub(pattern, '', x) for x in texts]

    # drop texts with Sign up or email patterns
    texts = [x for x in texts if re.search(r'([S|s]ign up)|([E|e]mail)', x) == None]

    # print('Dropping Tab patterns:\n', texts)

    # keep texts with small letter patterns
    pattern = r'([a-z]+\s){4}'
    texts = [x for x in texts if re.search(pattern, x) != None]

    # print('Keeping small letter patterns:\n', texts)


    # return NA if there are no text splits left
    if len(texts) == 0:
        return np.nan

    # Tokenize the title and texts
    tokenized_title = nltk.word_tokenize(title.lower())
    tokenized_texts = [nltk.word_tokenize(text.lower()) for text in texts]

    # Convert the tokenized texts to strings
    text_strings = [' '.join(tokens) for tokens in tokenized_texts]

    # print('Tokenized texts:\n', len(text_strings))

    # Create a TF-IDF vectorizer and fit it to the text strings
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(text_strings)
        # print(tfidf_matrix.shape)

    # Compute the cosine similarity between the title and each text
    title_vector = vectorizer.transform([' '.join(tokenized_title)])
    similarity_scores = cosine_similarity(title_vector, tfidf_matrix)

    most_similar_index = similarity_scores.argmax()
        
    most_similar_score = similarity_scores.max()
    index_to_return = most_similar_index
        
    list_articles = []
    list_scores = []

    for i in range(0,len(similarity_scores[0])):
        if similarity_scores[0][i] >= 0.07:
            list_articles.append(text_strings[i])
            list_scores.append(similarity_scores[0][i])
        # print(len(text_strings), len(similarity_scores[0]))
                
        # if len(text_strings) > 1:
        #     second_most_similar_index = similarity_scores.argsort()[0][-2]
        #     # print(similarity_scores)
        #     second_most_similar_score = similarity_scores[0][second_most_similar_index]
        #     if most_similar_score > 0.2:
        #         index_to_return = second_most_similar_index
        # # return texts[index_to_return]
        # return 

    # except:
    #     pass
    

    return ' '.join(list_articles)

# %%
# %%time
import time
from multiprocessing import Pool

most_similar = []
cnt = 0
batch_size = 500
total_batches = (len(df_news_final_project) + batch_size - 1) // batch_size

def process_item(i):
    return get_most_similar(i)

with Pool() as pool:
    for batch in range(total_batches):
        start_time = time.time()
        batch_indices = df_news_final_project.index.values[batch * batch_size: (batch + 1) * batch_size]
        results = pool.imap(process_item, batch_indices)

        for result in results:
            most_similar.append(result)

        end_time = time.time()
        batch_time = end_time - start_time
        print(f"Batch {batch + 1}/{total_batches} - Time spent: {batch_time:.2f} seconds")
    
df_news_final_project['text_clean'] = most_similar
df_news_final_project.dropna(subset=['text_clean'], inplace=True)
df_news_final_project.shape
# Out:
# Batch 1/401 - Time spent: 1.32 seconds
# Batch 2/401 - Time spent: 0.93 seconds
# Batch 3/401 - Time spent: 1.03 seconds
# Batch 4/401 - Time spent: 0.90 seconds
# Batch 5/401 - Time spent: 0.99 seconds
# Batch 6/401 - Time spent: 0.87 seconds
# Batch 7/401 - Time spent: 0.98 seconds
# Batch 8/401 - Time spent: 0.91 seconds
# Batch 9/401 - Time spent: 0.94 seconds
# Batch 10/401 - Time spent: 0.93 seconds
# Batch 11/401 - Time spent: 1.00 seconds
# Batch 12/401 - Time spent: 0.95 seconds
# Batch 13/401 - Time spent: 0.96 seconds
# Batch 14/401 - Time spent: 0.94 seconds
# Batch 15/401 - Time spent: 0.97 seconds
# Batch 16/401 - Time spent: 0.95 seconds
# Batch 17/401 - Time spent: 0.99 seconds
# Batch 18/401 - Time spent: 0.91 seconds
# Batch 19/401 - Time spent: 0.93 seconds
# Batch 20/401 - Time spent: 0.91 seconds
# Batch 21/401 - Time spent: 0.95 seconds
# Batch 22/401 - Time spent: 0.97 seconds
# Batch 23/401 - Time spent: 0.93 seconds
# Batch 24/401 - Time spent: 0.95 seconds
# Batch 25/401 - Time spent: 0.89 seconds
# Batch 26/401 - Time spent: 1.13 seconds
# Batch 27/401 - Time spent: 0.88 seconds
# Batch 28/401 - Time spent: 0.94 seconds
# Batch 29/401 - Time spent: 0.94 seconds
# Batch 30/401 - Time spent: 0.99 seconds
# Batch 31/401 - Time spent: 0.95 seconds
# Batch 32/401 - Time spent: 0.96 seconds
# Batch 33/401 - Time spent: 0.95 seconds
# Batch 34/401 - Time spent: 0.94 seconds
# Batch 35/401 - Time spent: 0.90 seconds
# Batch 36/401 - Time spent: 1.00 seconds
# Batch 37/401 - Time spent: 1.03 seconds
# Batch 38/401 - Time spent: 1.14 seconds
# Batch 39/401 - Time spent: 1.04 seconds
# Batch 40/401 - Time spent: 1.02 seconds
# Batch 41/401 - Time spent: 0.94 seconds
# Batch 42/401 - Time spent: 0.98 seconds
# Batch 43/401 - Time spent: 0.90 seconds
# Batch 44/401 - Time spent: 0.95 seconds
# Batch 45/401 - Time spent: 0.93 seconds
# Batch 46/401 - Time spent: 1.01 seconds
# Batch 47/401 - Time spent: 0.90 seconds
# Batch 48/401 - Time spent: 0.94 seconds
# Batch 49/401 - Time spent: 0.90 seconds
# Batch 50/401 - Time spent: 1.18 seconds
# Batch 51/401 - Time spent: 0.98 seconds
# Batch 52/401 - Time spent: 0.95 seconds
# Batch 53/401 - Time spent: 0.96 seconds
# Batch 54/401 - Time spent: 0.93 seconds
# Batch 55/401 - Time spent: 0.94 seconds
# Batch 56/401 - Time spent: 0.98 seconds
# Batch 57/401 - Time spent: 0.92 seconds
# Batch 58/401 - Time spent: 0.94 seconds
# Batch 59/401 - Time spent: 0.91 seconds
# Batch 60/401 - Time spent: 1.00 seconds
# Batch 61/401 - Time spent: 0.87 seconds
# Batch 62/401 - Time spent: 0.99 seconds
# Batch 63/401 - Time spent: 0.93 seconds
# Batch 64/401 - Time spent: 1.01 seconds
# Batch 65/401 - Time spent: 0.94 seconds
# Batch 66/401 - Time spent: 1.01 seconds
# Batch 67/401 - Time spent: 0.87 seconds
# Batch 68/401 - Time spent: 1.03 seconds
# Batch 69/401 - Time spent: 0.87 seconds
# Batch 70/401 - Time spent: 0.94 seconds
# Batch 71/401 - Time spent: 0.85 seconds
# Batch 72/401 - Time spent: 1.00 seconds
# Batch 73/401 - Time spent: 0.86 seconds
# Batch 74/401 - Time spent: 1.02 seconds
# Batch 75/401 - Time spent: 0.91 seconds
# Batch 76/401 - Time spent: 1.02 seconds
# Batch 77/401 - Time spent: 0.92 seconds
# Batch 78/401 - Time spent: 0.99 seconds
# Batch 79/401 - Time spent: 0.92 seconds
# Batch 80/401 - Time spent: 0.99 seconds
# Batch 81/401 - Time spent: 0.94 seconds
# Batch 82/401 - Time spent: 1.03 seconds
# Batch 83/401 - Time spent: 0.91 seconds
# Batch 84/401 - Time spent: 0.99 seconds
# Batch 85/401 - Time spent: 0.92 seconds
# Batch 86/401 - Time spent: 0.99 seconds
# Batch 87/401 - Time spent: 0.95 seconds
# Batch 88/401 - Time spent: 1.01 seconds
# Batch 89/401 - Time spent: 0.93 seconds
# Batch 90/401 - Time spent: 1.05 seconds
# Batch 91/401 - Time spent: 0.97 seconds
# Batch 92/401 - Time spent: 1.06 seconds
# Batch 93/401 - Time spent: 0.95 seconds
# Batch 94/401 - Time spent: 1.02 seconds
# Batch 95/401 - Time spent: 0.92 seconds
# Batch 96/401 - Time spent: 1.02 seconds
# Batch 97/401 - Time spent: 0.92 seconds
# Batch 98/401 - Time spent: 1.05 seconds
# Batch 99/401 - Time spent: 1.12 seconds
# Batch 100/401 - Time spent: 1.20 seconds
# Batch 101/401 - Time spent: 1.17 seconds
# Batch 102/401 - Time spent: 1.13 seconds
# Batch 103/401 - Time spent: 0.92 seconds
# Batch 104/401 - Time spent: 1.01 seconds
# Batch 105/401 - Time spent: 1.02 seconds
# Batch 106/401 - Time spent: 0.94 seconds
# Batch 107/401 - Time spent: 0.96 seconds
# Batch 108/401 - Time spent: 1.14 seconds
# Batch 109/401 - Time spent: 1.02 seconds
# Batch 110/401 - Time spent: 0.97 seconds
# Batch 111/401 - Time spent: 1.02 seconds
# Batch 112/401 - Time spent: 1.12 seconds
# Batch 113/401 - Time spent: 1.07 seconds
# Batch 114/401 - Time spent: 1.07 seconds
# Batch 115/401 - Time spent: 0.97 seconds
# Batch 116/401 - Time spent: 1.00 seconds
# Batch 117/401 - Time spent: 0.91 seconds
# Batch 118/401 - Time spent: 0.93 seconds
# Batch 119/401 - Time spent: 0.96 seconds
# Batch 120/401 - Time spent: 1.02 seconds
# Batch 121/401 - Time spent: 1.06 seconds
# Batch 122/401 - Time spent: 1.03 seconds
# Batch 123/401 - Time spent: 0.93 seconds
# Batch 124/401 - Time spent: 1.00 seconds
# Batch 125/401 - Time spent: 0.98 seconds
# Batch 126/401 - Time spent: 1.06 seconds
# Batch 127/401 - Time spent: 0.94 seconds
# Batch 128/401 - Time spent: 1.09 seconds
# Batch 129/401 - Time spent: 0.96 seconds
# Batch 130/401 - Time spent: 1.02 seconds
# Batch 131/401 - Time spent: 0.95 seconds
# Batch 132/401 - Time spent: 1.04 seconds
# Batch 133/401 - Time spent: 0.97 seconds
# Batch 134/401 - Time spent: 0.98 seconds
# Batch 135/401 - Time spent: 0.98 seconds
# Batch 136/401 - Time spent: 0.99 seconds
# Batch 137/401 - Time spent: 0.99 seconds
# Batch 138/401 - Time spent: 0.97 seconds
# Batch 139/401 - Time spent: 0.95 seconds
# Batch 140/401 - Time spent: 1.02 seconds
# Batch 141/401 - Time spent: 0.96 seconds
# Batch 142/401 - Time spent: 1.00 seconds
# Batch 143/401 - Time spent: 0.95 seconds
# Batch 144/401 - Time spent: 1.00 seconds
# Batch 145/401 - Time spent: 0.97 seconds
# Batch 146/401 - Time spent: 0.99 seconds
# Batch 147/401 - Time spent: 0.97 seconds
# Batch 148/401 - Time spent: 1.02 seconds
# Batch 149/401 - Time spent: 0.93 seconds
# Batch 150/401 - Time spent: 0.99 seconds
# Batch 151/401 - Time spent: 0.99 seconds
# Batch 152/401 - Time spent: 1.02 seconds
# Batch 153/401 - Time spent: 0.96 seconds
# Batch 154/401 - Time spent: 1.01 seconds
# Batch 155/401 - Time spent: 0.95 seconds
# Batch 156/401 - Time spent: 0.98 seconds
# Batch 157/401 - Time spent: 0.98 seconds
# Batch 158/401 - Time spent: 0.99 seconds
# Batch 159/401 - Time spent: 1.06 seconds
# Batch 160/401 - Time spent: 1.22 seconds
# Batch 161/401 - Time spent: 1.15 seconds
# Batch 162/401 - Time spent: 1.15 seconds
# Batch 163/401 - Time spent: 1.00 seconds
# Batch 164/401 - Time spent: 0.97 seconds
# Batch 165/401 - Time spent: 1.04 seconds
# Batch 166/401 - Time spent: 0.98 seconds
# Batch 167/401 - Time spent: 1.00 seconds
# Batch 168/401 - Time spent: 0.98 seconds
# Batch 169/401 - Time spent: 1.00 seconds
# Batch 170/401 - Time spent: 0.94 seconds
# Batch 171/401 - Time spent: 0.96 seconds
# Batch 172/401 - Time spent: 1.01 seconds
# Batch 173/401 - Time spent: 0.98 seconds
# Batch 174/401 - Time spent: 1.19 seconds
# Batch 175/401 - Time spent: 1.03 seconds
# Batch 176/401 - Time spent: 1.00 seconds
# Batch 177/401 - Time spent: 0.95 seconds
# Batch 178/401 - Time spent: 1.00 seconds
# Batch 179/401 - Time spent: 0.87 seconds
# Batch 180/401 - Time spent: 0.99 seconds
# Batch 181/401 - Time spent: 0.94 seconds
# Batch 182/401 - Time spent: 1.01 seconds
# Batch 183/401 - Time spent: 0.93 seconds
# Batch 184/401 - Time spent: 0.99 seconds
# Batch 185/401 - Time spent: 0.89 seconds
# Batch 186/401 - Time spent: 1.03 seconds
# Batch 187/401 - Time spent: 0.91 seconds
# Batch 188/401 - Time spent: 1.01 seconds
# Batch 189/401 - Time spent: 0.92 seconds
# Batch 190/401 - Time spent: 0.98 seconds
# Batch 191/401 - Time spent: 0.92 seconds
# Batch 192/401 - Time spent: 0.96 seconds
# Batch 193/401 - Time spent: 0.92 seconds
# Batch 194/401 - Time spent: 1.02 seconds
# Batch 195/401 - Time spent: 0.93 seconds
# Batch 196/401 - Time spent: 1.04 seconds
# Batch 197/401 - Time spent: 0.91 seconds
# Batch 198/401 - Time spent: 1.05 seconds
# Batch 199/401 - Time spent: 0.89 seconds
# Batch 200/401 - Time spent: 1.12 seconds
# Batch 201/401 - Time spent: 0.91 seconds
# Batch 202/401 - Time spent: 1.03 seconds
# Batch 203/401 - Time spent: 0.95 seconds
# Batch 204/401 - Time spent: 1.00 seconds
# Batch 205/401 - Time spent: 1.01 seconds
# Batch 206/401 - Time spent: 0.95 seconds
# Batch 207/401 - Time spent: 1.00 seconds
# Batch 208/401 - Time spent: 1.03 seconds
# Batch 209/401 - Time spent: 0.98 seconds
# Batch 210/401 - Time spent: 1.06 seconds
# Batch 211/401 - Time spent: 1.04 seconds
# Batch 212/401 - Time spent: 1.03 seconds
# Batch 213/401 - Time spent: 0.98 seconds
# Batch 214/401 - Time spent: 1.03 seconds
# Batch 215/401 - Time spent: 0.95 seconds
# Batch 216/401 - Time spent: 1.04 seconds
# Batch 217/401 - Time spent: 0.97 seconds
# Batch 218/401 - Time spent: 1.05 seconds
# Batch 219/401 - Time spent: 1.05 seconds
# Batch 220/401 - Time spent: 1.14 seconds
# Batch 221/401 - Time spent: 1.09 seconds
# Batch 222/401 - Time spent: 1.12 seconds
# Batch 223/401 - Time spent: 1.00 seconds
# Batch 224/401 - Time spent: 0.94 seconds
# Batch 225/401 - Time spent: 1.00 seconds
# Batch 226/401 - Time spent: 1.20 seconds
# Batch 227/401 - Time spent: 0.98 seconds
# Batch 228/401 - Time spent: 0.98 seconds
# Batch 229/401 - Time spent: 0.99 seconds
# Batch 230/401 - Time spent: 0.98 seconds
# Batch 231/401 - Time spent: 0.97 seconds
# Batch 232/401 - Time spent: 1.03 seconds
# Batch 233/401 - Time spent: 0.93 seconds
# Batch 234/401 - Time spent: 1.02 seconds
# Batch 235/401 - Time spent: 1.05 seconds
# Batch 236/401 - Time spent: 1.16 seconds
# Batch 237/401 - Time spent: 1.02 seconds
# Batch 238/401 - Time spent: 1.04 seconds
# Batch 239/401 - Time spent: 0.95 seconds
# Batch 240/401 - Time spent: 1.02 seconds
# Batch 241/401 - Time spent: 0.98 seconds
# Batch 242/401 - Time spent: 1.04 seconds
# Batch 243/401 - Time spent: 0.97 seconds
# Batch 244/401 - Time spent: 1.01 seconds
# Batch 245/401 - Time spent: 0.99 seconds
# Batch 246/401 - Time spent: 1.06 seconds
# Batch 247/401 - Time spent: 0.98 seconds
# Batch 248/401 - Time spent: 1.04 seconds
# Batch 249/401 - Time spent: 0.99 seconds
# Batch 250/401 - Time spent: 1.03 seconds
# Batch 251/401 - Time spent: 1.00 seconds
# Batch 252/401 - Time spent: 0.99 seconds
# Batch 253/401 - Time spent: 1.03 seconds
# Batch 254/401 - Time spent: 1.02 seconds
# Batch 255/401 - Time spent: 0.98 seconds
# Batch 256/401 - Time spent: 1.01 seconds
# Batch 257/401 - Time spent: 0.98 seconds
# Batch 258/401 - Time spent: 1.03 seconds
# Batch 259/401 - Time spent: 0.96 seconds
# Batch 260/401 - Time spent: 1.08 seconds
# Batch 261/401 - Time spent: 0.95 seconds
# Batch 262/401 - Time spent: 1.07 seconds
# Batch 263/401 - Time spent: 1.07 seconds
# Batch 264/401 - Time spent: 0.99 seconds
# Batch 265/401 - Time spent: 0.99 seconds
# Batch 266/401 - Time spent: 1.06 seconds
# Batch 267/401 - Time spent: 0.98 seconds
# Batch 268/401 - Time spent: 1.08 seconds
# Batch 269/401 - Time spent: 0.92 seconds
# Batch 270/401 - Time spent: 0.99 seconds
# Batch 271/401 - Time spent: 0.92 seconds
# Batch 272/401 - Time spent: 0.98 seconds
# Batch 273/401 - Time spent: 0.96 seconds
# Batch 274/401 - Time spent: 1.01 seconds
# Batch 275/401 - Time spent: 0.92 seconds
# Batch 276/401 - Time spent: 1.08 seconds
# Batch 277/401 - Time spent: 0.98 seconds
# Batch 278/401 - Time spent: 1.19 seconds
# Batch 279/401 - Time spent: 1.08 seconds
# Batch 280/401 - Time spent: 1.08 seconds
# Batch 281/401 - Time spent: 1.08 seconds
# Batch 282/401 - Time spent: 1.06 seconds
# Batch 283/401 - Time spent: 0.92 seconds
# Batch 284/401 - Time spent: 1.05 seconds
# Batch 285/401 - Time spent: 0.93 seconds
# Batch 286/401 - Time spent: 1.05 seconds
# Batch 287/401 - Time spent: 0.90 seconds
# Batch 288/401 - Time spent: 1.07 seconds
# Batch 289/401 - Time spent: 0.91 seconds
# Batch 290/401 - Time spent: 1.07 seconds
# Batch 291/401 - Time spent: 0.93 seconds
# Batch 292/401 - Time spent: 1.13 seconds
# Batch 293/401 - Time spent: 0.95 seconds
# Batch 294/401 - Time spent: 1.04 seconds
# Batch 295/401 - Time spent: 0.97 seconds
# Batch 296/401 - Time spent: 1.22 seconds
# Batch 297/401 - Time spent: 1.08 seconds
# Batch 298/401 - Time spent: 1.01 seconds
# Batch 299/401 - Time spent: 0.94 seconds
# Batch 300/401 - Time spent: 0.97 seconds
# Batch 301/401 - Time spent: 1.04 seconds
# Batch 302/401 - Time spent: 0.97 seconds
# Batch 303/401 - Time spent: 1.00 seconds
# Batch 304/401 - Time spent: 1.01 seconds
# Batch 305/401 - Time spent: 1.05 seconds
# Batch 306/401 - Time spent: 0.99 seconds
# Batch 307/401 - Time spent: 0.97 seconds
# Batch 308/401 - Time spent: 0.97 seconds
# Batch 309/401 - Time spent: 0.99 seconds
# Batch 310/401 - Time spent: 0.98 seconds
# Batch 311/401 - Time spent: 0.95 seconds
# Batch 312/401 - Time spent: 0.94 seconds
# Batch 313/401 - Time spent: 1.03 seconds
# Batch 314/401 - Time spent: 0.99 seconds
# Batch 315/401 - Time spent: 1.00 seconds
# Batch 316/401 - Time spent: 1.00 seconds
# Batch 317/401 - Time spent: 0.98 seconds
# Batch 318/401 - Time spent: 1.01 seconds
# Batch 319/401 - Time spent: 0.95 seconds
# Batch 320/401 - Time spent: 1.00 seconds
# Batch 321/401 - Time spent: 0.92 seconds
# Batch 322/401 - Time spent: 0.96 seconds
# Batch 323/401 - Time spent: 0.93 seconds
# Batch 324/401 - Time spent: 0.95 seconds
# Batch 325/401 - Time spent: 0.96 seconds
# Batch 326/401 - Time spent: 0.98 seconds
# Batch 327/401 - Time spent: 1.00 seconds
# Batch 328/401 - Time spent: 1.04 seconds
# Batch 329/401 - Time spent: 0.97 seconds
# Batch 330/401 - Time spent: 0.99 seconds
# Batch 331/401 - Time spent: 1.03 seconds
# Batch 332/401 - Time spent: 1.02 seconds
# Batch 333/401 - Time spent: 0.98 seconds
# Batch 334/401 - Time spent: 1.02 seconds
# Batch 335/401 - Time spent: 0.99 seconds
# Batch 336/401 - Time spent: 0.98 seconds
# Batch 337/401 - Time spent: 0.99 seconds
# Batch 338/401 - Time spent: 1.13 seconds
# Batch 339/401 - Time spent: 1.14 seconds
# Batch 340/401 - Time spent: 1.13 seconds
# Batch 341/401 - Time spent: 1.14 seconds
# Batch 342/401 - Time spent: 1.12 seconds
# Batch 343/401 - Time spent: 0.97 seconds
# Batch 344/401 - Time spent: 0.99 seconds
# Batch 345/401 - Time spent: 0.96 seconds
# Batch 346/401 - Time spent: 0.99 seconds
# Batch 347/401 - Time spent: 1.03 seconds
# Batch 348/401 - Time spent: 0.93 seconds
# Batch 349/401 - Time spent: 0.97 seconds
# Batch 350/401 - Time spent: 1.01 seconds
# Batch 351/401 - Time spent: 0.98 seconds
# Batch 352/401 - Time spent: 0.95 seconds
# Batch 353/401 - Time spent: 1.04 seconds
# Batch 354/401 - Time spent: 0.94 seconds
# Batch 355/401 - Time spent: 0.97 seconds
# Batch 356/401 - Time spent: 0.97 seconds
# Batch 357/401 - Time spent: 1.11 seconds
# Batch 358/401 - Time spent: 1.09 seconds
# Batch 359/401 - Time spent: 1.11 seconds
# Batch 360/401 - Time spent: 0.99 seconds
# Batch 361/401 - Time spent: 0.94 seconds
# Batch 362/401 - Time spent: 0.95 seconds
# Batch 363/401 - Time spent: 0.95 seconds
# Batch 364/401 - Time spent: 0.97 seconds
# Batch 365/401 - Time spent: 1.01 seconds
# Batch 366/401 - Time spent: 1.02 seconds
# Batch 367/401 - Time spent: 0.92 seconds
# Batch 368/401 - Time spent: 1.05 seconds
# Batch 369/401 - Time spent: 1.02 seconds
# Batch 370/401 - Time spent: 1.00 seconds
# Batch 371/401 - Time spent: 0.97 seconds
# Batch 372/401 - Time spent: 0.98 seconds
# Batch 373/401 - Time spent: 1.04 seconds
# Batch 374/401 - Time spent: 1.02 seconds
# Batch 375/401 - Time spent: 0.96 seconds
# Batch 376/401 - Time spent: 0.98 seconds
# Batch 377/401 - Time spent: 1.00 seconds
# Batch 378/401 - Time spent: 0.97 seconds
# Batch 379/401 - Time spent: 1.05 seconds
# Batch 380/401 - Time spent: 1.05 seconds
# Batch 381/401 - Time spent: 1.01 seconds
# Batch 382/401 - Time spent: 0.96 seconds
# Batch 383/401 - Time spent: 1.00 seconds
# Batch 384/401 - Time spent: 0.99 seconds
# Batch 385/401 - Time spent: 0.96 seconds
# Batch 386/401 - Time spent: 0.95 seconds
# Batch 387/401 - Time spent: 0.98 seconds
# Batch 388/401 - Time spent: 0.96 seconds
# Batch 389/401 - Time spent: 1.04 seconds
# Batch 390/401 - Time spent: 0.93 seconds
# Batch 391/401 - Time spent: 0.98 seconds
# Batch 392/401 - Time spent: 0.97 seconds
# Batch 393/401 - Time spent: 0.99 seconds
# Batch 394/401 - Time spent: 1.05 seconds
# Batch 395/401 - Time spent: 0.91 seconds
# Batch 396/401 - Time spent: 1.04 seconds
# Batch 397/401 - Time spent: 1.01 seconds
# Batch 398/401 - Time spent: 1.09 seconds
# Batch 399/401 - Time spent: 1.03 seconds
# Batch 400/401 - Time spent: 1.07 seconds
# Batch 401/401 - Time spent: 0.68 seconds
# CPU times: user 21 s, sys: 8.65 s, total: 29.7 s
# Wall time: 6min 41s
# (190013, 9)

# %%
df_news_final_project.head(10)
# Out:
#                                                  url        date language  \
# 0  http://en.people.cn/n3/2021/0318/c90000-983012...  2021-03-18       en
# 1  http://newsparliament.com/2020/02/27/children-...  2020-02-27       en
# 2                   http://www.dataweek.co.za/12835r  2021-03-26       en
# 3  http://www.homeoffice.consumerelectronicsnet.c...  2021-03-10       en
# 4  http://www.itbusinessnet.com/2020/10/olympus-t...  2020-10-20       en
# 5  http://www.mysmartrend.com/news-briefs/technic...  2020-04-17       en
# 6  http://www.pentictonherald.ca/entertainment/na...  2020-12-08       en
# 7  http://www.peripherals.consumerelectronicsnet....  2021-02-25       en
# 8  http://www.productivityapps.itbusinessnet.com/...  2020-06-23       en
# 9  https://3wnews.org/uncategorised/1351502/artif...  2020-06-14       en
#
#                                                title  \
# 0  Artificial intelligence improves parking effic...
# 1  Children With Autism Saw Their Learning and So...
# 2  Forget ML, AI and Industry 4.0 – obsolescence ...
# 3  Strategy Analytics: 71% of Smartphones Sold Gl...
# 4  Olympus to Support Endoscopic AI Diagnosis Edu...
# 5  Cr Bard Inc Has Returned 48.9% Since SmarTrend...
# 6  From the Bard to broadcaster: Stratford Festiv...
# 7  MulticoreWare Inc. Becomes CEVA’s Trusted Part...
# 8  Applitools Visual AI Reaches One Billion Image...
# 9  Artificial Intelligence In Behavioral And Ment...
#
#                                                 text  \
# 0  \n\nArtificial intelligence improves parking e...
# 1  \nChildren With Autism Saw Their Learning and ...
# 2  \n\nForget ML, AI and Industry 4.0 – obsolesce...
# 3  \n\nStrategy Analytics: 71% of Smartphones Sol...
# 4  \n\nOlympus to Support Endoscopic AI Diagnosis...
# 5  \n\nCr Bard Inc Has Returned 48.9% Since SmarT...
# 6  \n\nFrom the Bard to broadcaster: Stratford Fe...
# 7  \n\nMulticoreWare Inc. Becomes CEVA’s Trusted ...
# 8  \n\nApplitools Visual AI Reaches One Billion I...
# 9  \nArtificial Intelligence In Behavioral And Me...
#
#                                           text_clean  \
# 0  thanks to the application of an artificial int...
# 1  scientists who designed an artificially clever...
# 2  the world entered a new era of accelerated tra...
# 3  boston– ( business wire ) –strategy analytics ...
# 4  – ( acn newswire ) – olympus corporation took ...
# 5  smartrend identified an uptrend for cr bard in...
# 6  . stratford , ont. , stage star alexis gordon ...
# 7  multicoreware inc. , joins the cevanet™ partne...
# 8  /prnewswire/ — applitools ( https : //applitoo...
# 9  artificial intelligence in behavioral and ment...
#
#                                         text_notitle  \
# 0  \n\nHahahah 23, 2026\n\nHome\nChina Politics\n...
# 1  \nHahahah 23, 2026\n \n\nSkip to content\n   T...
# 2  \n\nHahahah 23, 2026\nHome\nAbout us\nBack iss...
# 3  \n\nHahahah 23, 2026\n \nSkip to content\n\nCo...
# 4  \n\nHahahah 23, 2026\n \nSkip to content\n\nIT...
# 5  \n\nHahahah 23, 2026\n \nOWL LOGIN  /  \n     ...
# 6  \n\nHahahah 23, 2026\n\nYou have permission to...
# 7  \n\nHahahah 23, 2026\n\n \nSkip to content\n\n...
# 8  \n\nHahahah 23, 2026\n\n \nSkip to content\n\n...
# 9  \nHahahah 23, 2026\n\nSkip to content\nSunday,...
#
#                                                split  split_len
# 0  [, None, None, , Hahahah 23, 2026, None, , Non...        190
# 1  [, None, None, , Hahahah 23, 2026, None, , Non...        571
# 2  [, None, None, , Hahahah 23, 2026, None, , Non...        457
# 3  [, None, None, , Hahahah 23, 2026, None, , Non...         91
# 4  [, None, None, , Hahahah 23, 2026, None, , Non...       1468
# 5  [, None, None, , Hahahah 23, 2026, None, , Non...        184
# 6  [, None, None, , Hahahah 23, 2026, None, , Non...        859
# 7  [, None, None, , Hahahah 23, 2026, None, , Non...         76
# 8  [, None, None, , Hahahah 23, 2026, None, , Non...        124
# 9  [, None, None, , Hahahah 23, 2026, None, , Non...        253

# %%
df_news_final_project.to_csv('/home/jupyter/df_news.csv')

# %%
# df_news_final_project
# Out:
#                                                       url        date  \
# 0       http://en.people.cn/n3/2021/0318/c90000-983012...  2021-03-18
# 1       http://newsparliament.com/2020/02/27/children-...  2020-02-27
# 2                        http://www.dataweek.co.za/12835r  2021-03-26
# 3       http://www.homeoffice.consumerelectronicsnet.c...  2021-03-10
# 4       http://www.itbusinessnet.com/2020/10/olympus-t...  2020-10-20
# ...                                                   ...         ...
# 200327  https://www.zazoom.it/2020-12-14/comviva-and-o...  2020-12-14
# 200328  https://www.zdnet.com/article/afp-used-clearvi...  2020-04-15
# 200329  https://www.zdnet.com/article/from-data-to-kno...  2020-12-22
# 200330  https://yourstory.com/2020/10/ys-learn-helping...  2020-10-07
# 200331  https://yourstory.com/2021/05/startups-covid-1...  2021-05-06
#
#        language                                              title  \
# 0            en  Artificial intelligence improves parking effic...
# 1            en  Children With Autism Saw Their Learning and So...
# 2            en  Forget ML, AI and Industry 4.0 – obsolescence ...
# 3            en  Strategy Analytics: 71% of Smartphones Sold Gl...
# 4            en  Olympus to Support Endoscopic AI Diagnosis Edu...
# ...         ...                                                ...
# 200327       en  Comviva and Ooredoo Kuwait form strategic part...
# 200328       en  AFP used Clearview AI facial recognition softw...
# 200329       en  From data to knowledge and AI via graphs: Tech...
# 200330       en  [YS Learn] From helping diabetic patients to m...
# 200331       en  Startups fight COVID-19: Slang Labs is using v...
#
#                                                      text  \
# 0       \n\nArtificial intelligence improves parking e...
# 1       \nChildren With Autism Saw Their Learning and ...
# 2       \n\nForget ML, AI and Industry 4.0 – obsolesce...
# 3       \n\nStrategy Analytics: 71% of Smartphones Sol...
# 4       \n\nOlympus to Support Endoscopic AI Diagnosis...
# ...                                                   ...
# 200327  \n\nComviva and Ooredoo Kuwait form strategic ...
# 200328  AFP used Clearview AI facial recognition softw...
# 200329  \n\nFrom data to knowledge and AI via graphs: ...
# 200330  [YS Learn] From helping diabetic patients to m...
# 200331  Startups fight COVID-19: Slang Labs is using v...
#
#                                                text_clean  \
# 0       thanks to the application of an artificial int...
# 1       scientists who designed an artificially clever...
# 2       the world entered a new era of accelerated tra...
# 3       boston– ( business wire ) –strategy analytics ...
# 4       – ( acn newswire ) – olympus corporation took ...
# ...                                                   ...
# 200327  /prnewswire/ comviva , the global leader in mo...
# 200328  the australian federal police ( afp ) has admi...
# 200329  in the new knowledge-based digital world , enc...
# 200330  by sindhu kashyaap|7th oct 2020the minimum via...
# 200331  slang labs 's co-founder kumar rangarajan shar...
#
#                                              text_notitle  \
# 0       \n\nHahahah 23, 2026\n\nHome\nChina Politics\n...
# 1       \nHahahah 23, 2026\n \n\nSkip to content\n   T...
# 2       \n\nHahahah 23, 2026\nHome\nAbout us\nBack iss...
# 3       \n\nHahahah 23, 2026\n \nSkip to content\n\nCo...
# 4       \n\nHahahah 23, 2026\n \nSkip to content\n\nIT...
# ...                                                   ...
# 200327  \n\nHahahah 23, 2026\n\nAccedi\n\n\nHome\n\n\n...
# 200328  Hahahah 23, 2026\n\n                          ...
# 200329  \n\nHahahah 23, 2026\n\n   \n\n               ...
# 200330  Hahahah 23, 2026LOGINYourStoryEducationHerStor...
# 200331  Hahahah 23, 2026                LOGIN \n\n  ✕ ...
#
#                                                     split  split_len
# 0       [, None, None, , Hahahah 23, 2026, None, , Non...        190
# 1       [, None, None, , Hahahah 23, 2026, None, , Non...        571
# 2       [, None, None, , Hahahah 23, 2026, None, , Non...        457
# 3       [, None, None, , Hahahah 23, 2026, None, , Non...         91
# 4       [, None, None, , Hahahah 23, 2026, None, , Non...       1468
# ...                                                   ...        ...
# 200327  [, None, None, , Hahahah 23, 2026, None, , Non...        205
# 200328  [, Hahahah 23, 2026, None, , None, None,      ...       1318
# 200329  [, None, None, , Hahahah 23, 2026, None, , Non...       1030
# 200330  [, Hahahah 23, 2026, None, LOGINYourStoryEduca...         37
# 200331  [, Hahahah 23, 2026, None,                 LOG...         34
#
# [190013 rows x 9 columns]
